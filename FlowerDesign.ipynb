# %%
# !pip install ColabTurtlePlus==2.0
from ColabTurtlePlus.Turtle import *
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import colorsys

# %%
hideturtle()
speed(13)# 13 is the max 
bgcolor('black')
width(1) # set the width of the line 
#create a variable 
c = 0.0 
for i in range(50): # 50 iterations of 
    color(getcolor(c)) # grabing a color from a value 
    for j in range(10): # within each of those 50 iterations is 10 iterations of. cannot start at 0 because cannot have a radius of zero 
        circle(i+1*95) # creating a circle of the input parameter length 
        right(36)# shifting the cursor to the right 30 degrees (1/10 of a circle)
    c += 2.78 # increase the color value 
saveSVG()
done()
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:black;stroke:;stroke-width:1"/>
#
#
#         <path d="M 400.0 300.0 A 95 95 0 0 0 400.0 110.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 400.0 110.0 A 95 95 0 0 0 400.0 300.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 400.0 300.0 A 95 95 0 0 0 511.679 146.287" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 511.679 146.287 A 95 95 0 0 0 400.0 300.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 400.0 300.0 A 95 95 0 0 0 580.701 241.287" stroke-linecap="round"
# ...
